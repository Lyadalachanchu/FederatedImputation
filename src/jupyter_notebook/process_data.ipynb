# %%
import numpy as np
import pickle
import matplotlib.pyplot as plt

# %%
# Performance of VAE

# %%
clients_data = []
for dirichlet in np.linspace(0.1,1, 10):
    dirichlet = round(dirichlet, 1)
    path = f"C:\\Users\\lyada\\Desktop\\Federated-Learning-PyTorch\\TheArchive\\objects\\{dirichlet}_mnist_vae_30_C[1.0]_iid[2]_E[10]_B[10].pkl"
    with open(path, 'rb') as f:
        clients_data.append(pickle.load(f))
    plt.plot(np.mean(clients_data[-1][1], axis=0), label = f"vae_{dirichlet}")

plt.title("Average Test Loss vs Global Round on MNIST")
plt.xlabel('Global Round')
plt.ylabel('Test Loss')

plt.legend()
plt.show()

# %%
# Performance of VAE as non-iidness increases
clients_data = []
for dirichlet in np.linspace(0.1,1, 10):
    dirichlet = round(dirichlet, 1)
    path = f"C:\\Users\\lyada\\Desktop\\Federated-Learning-PyTorch\\TheArchive\\objects\\{dirichlet}_mnist_vae_30_C[1.0]_iid[2]_E[10]_B[10].pkl"
    with open(path, 'rb') as f:
        clients_data.append(pickle.load(f))
    plt.plot(np.mean(clients_data[-1][2], axis=0), label = f"vae_{dirichlet}")

plt.title("Average Test Accuracy vs Global Round on MNIST")
plt.xlabel('Global Round')
plt.ylabel('Test Loss')

plt.legend()
plt.show()

# %%
# Performance of classifier as non-iidness increases

# %%
clients_data = []
# dirichlets = [0.1, 0.3, 0.5, 0.8, 1.0]
dirichlets = [0.1, 0.3, 0.5, 1.0]
for dirichlet in dirichlets:
    dirichlet = round(dirichlet, 1)
    # C:\Users\LohithSai\Desktop\FederatedImputation\TheArchive\imputation_experiments\run_one\fedimputed_cvae_0_0.1_mnist_exq_15_C[1.0]_iid[2]_E[1]_B[10].pkl
    path = f"C:\\Users\\LohithSai\\Desktop\\FederatedImputation\\TheArchive\\imputation_experiments\\run_one\\fedimputed_cvae_0_{dirichlet}_mnist_exq_15_C[1.0]_iid[2]_E[1]_B[10].pkl"
    with open(path, 'rb') as f:
        clients_data.append(pickle.load(f))
    plt.plot(np.mean(clients_data[-1][1], axis=0), label = f"classifier_{dirichlet}")

plt.title("Average Test Loss vs Global Round on MNIST")
plt.xlabel('Global Round')
plt.ylabel('Test Loss')

plt.legend()
plt.show()

# %%
clients_data = []
dirichlets = [0.1, 0.3, 0.5, 1.0]

for dirichlet in dirichlets:
    dirichlet = round(dirichlet, 1)
    path = f"C:\\Users\\LohithSai\\Desktop\\FederatedImputation\\TheArchive\\imputation_experiments\\run_one\\fedimputed_cvae_0_{dirichlet}_mnist_exq_15_C[1.0]_iid[2]_E[1]_B[10].pkl"
    with open(path, 'rb') as f:
        clients_data.append(pickle.load(f))
    plt.plot(np.mean(clients_data[-1][2], axis=0), label = f"classifer_{dirichlet}")

plt.title("Average Test Accuracy vs Global Round on MNIST")
plt.xlabel('Global Round')
plt.ylabel('Test Accuracy')

plt.legend()
plt.show()

# %%
# Performance of classifier (for each non-iidness) as k (num imputed datapoints increases)

# %%
clients_data = []
ks = [0, 750, 1500, 3000, 6000]
dirichlets = [0.1, 0.3, 0.5, 1.0]
fig, axes = plt.subplots(2, 3, figsize=(15, 8))
axes = axes.flatten()

for i, k in enumerate(ks):
    for dirichlet in dirichlets:
        dirichlet = round(dirichlet, 1)
        path = f"C:\\Users\\LohithSai\\Desktop\\FederatedImputation\\TheArchive\\imputation_experiments\\run_one\\fedimputed_cvae_{k}_{dirichlet}_mnist_exq_15_C[1.0]_iid[2]_E[1]_B[10].pkl"
        with open(path, 'rb') as f:
            clients_data.append(pickle.load(f))
        axes[i].plot(np.mean(clients_data[-1][1], axis=0), label=f"classifier_{dirichlet}")

    axes[i].set_title("k = " + str(k))
    axes[i].set_xlabel('Global Round')
    axes[i].set_ylabel('Test Loss')

    axes[i].legend()

plt.tight_layout()
plt.show()

# %%
clients_data = []
ks = [0, 100, 750, 1500, 3000, 6000]

fig, axes = plt.subplots(2, 3, figsize=(15, 8))
axes = axes.flatten()

for i, k in enumerate(ks):
    for dirichlet in dirichlets:
        dirichlet = round(dirichlet, 1)
        path = f"C:\\Users\\LohithSai\\Desktop\\FederatedImputation\\TheArchive\\imputation_experiments\\run_one\\fedimputed_cvae_{k}_{dirichlet}_mnist_exq_15_C[1.0]_iid[2]_E[1]_B[10].pkl"
        with open(path, 'rb') as f:
            clients_data.append(pickle.load(f))
        axes[i].plot(np.mean(clients_data[-1][2], axis=0), label=f"classifier_{dirichlet}")

    axes[i].set_title("k = " + str(k))
    axes[i].set_xlabel('Global Round')
    axes[i].set_ylabel('Test Loss')

    axes[i].legend()

plt.tight_layout()
plt.show()

# %%
# This aggregates all the dirchlets for each k
clients_data = []
# ks = [0, 100, 750, 1500, 3000, 6000]
ks = [0, 750, 1500, 3000, 6000]
for k in ks:
    dirch_metrics = []
    for dirichlet in dirichlets:
        dirichlet = round(dirichlet, 1)
        path = f"C:\\Users\\LohithSai\\Desktop\\FederatedImputation\\TheArchive\\imputation_experiments\\run_one\\fedimputed_cvae_{k}_{dirichlet}_mnist_exq_15_C[1.0]_iid[2]_E[1]_B[10].pkl"
        with open(path, 'rb') as f:
            clients_data.append(pickle.load(f))
        # plt.plot(np.mean(clients_data[-1][1], axis=0), label = f"classifier_{dirichlet}")
        dirch_metrics.append(np.mean(clients_data[-1][1], axis=0))
        print(f"k: {k}, dirichlet: {dirichlet}, {clients_data[-1][3]}")
    print("\n")
    dirch_metrics = np.array(dirch_metrics)
    plt.plot(np.mean(dirch_metrics, axis=0), label = f"classifier_dirichlet_{k}")
    # print(len(np.mean(clients_data[-1][1], axis=0)))
    plt.title("Average Test Loss vs Global Round on MNIST")
    plt.xlabel('Global Round')
    plt.ylabel('Test Loss')

plt.legend()
plt.show()
# Out:
# k: 0, dirichlet: 0.1, 0.9295124884884143
# k: 0, dirichlet: 0.3, 0.9644789246310559
# k: 0, dirichlet: 0.5, 0.9573104742402896
# k: 0, dirichlet: 1.0, 0.9655466055454692
#
#
# k: 750, dirichlet: 0.1, 0.8942309542884297
# k: 750, dirichlet: 0.3, 0.9658213883148796
# k: 750, dirichlet: 0.5, 0.9521682563661589
# k: 750, dirichlet: 1.0, 0.9646132063081145
#
#
# k: 1500, dirichlet: 0.1, 0.8682659900762897
# k: 1500, dirichlet: 0.3, 0.9554969364986391
# k: 1500, dirichlet: 0.5, 0.9652448595936743
# k: 1500, dirichlet: 1.0, 0.9693800782931012
#
#
# k: 3000, dirichlet: 0.1, 0.9223861102889558
# k: 3000, dirichlet: 0.3, 0.9570197733307412
# k: 3000, dirichlet: 0.5, 0.9217057546124675
# k: 3000, dirichlet: 1.0, 0.9653053552889977
#
#
# k: 6000, dirichlet: 0.1, 0.8994516886002408
# k: 6000, dirichlet: 0.3, 0.9580919006967219
# k: 6000, dirichlet: 0.5, 0.9581870760173224
# k: 6000, dirichlet: 1.0, 0.95839957914521

# %%
path = f"C:\\Users\\LohithSai\\Desktop\\FederatedImputation\\TheArchive\\imputation_experiments\\run_one\\fedimputed_cvae_{0}_{0.3}_mnist_exq_15_C[1.0]_iid[2]_E[1]_B[10].pkl"
clients_data = []
with open(path, 'rb') as f:
    clients_data.append(pickle.load(f))
clients_data[0][4]
#[][client_id][num_global_epochs]
# Out:
# 0.9647

# %%
# This aggregates all the dirchlets for each k
clients_data = []
# ks = [0, 100, 750, 1500, 3000, 6000]
ks = [0, 750, 1500, 3000, 6000]
for k in ks:
    dirch_metrics = []
    for dirichlet in np.linspace(0.1,1, 10):
        dirichlet = round(dirichlet, 1)
        path = f"C:\\Users\\lyada\\Desktop\\Federated-Learning-PyTorch\\save\\objects\\fedimputed_{k}_{dirichlet}_mnist_exq_15_C[1.0]_iid[2]_E[1]_B[10].pkl"
        with open(path, 'rb') as f:
            clients_data.append(pickle.load(f))
        # plt.plot(np.mean(clients_data[-1][1], axis=0), label = f"classifier_{dirichlet}")
        dirch_metrics.append(np.mean(clients_data[-1][2], axis=0))
    dirch_metrics = np.array(dirch_metrics)
    plt.plot(np.mean(dirch_metrics, axis=0), label = f"classifier_dirichlet_{k}")
    # print(len(np.mean(clients_data[-1][1], axis=0)))
    plt.title("Average Test Accuracy vs Global Round on MNIST")
    plt.xlabel('Global Round')
    plt.ylabel('Test Accuracy')

plt.legend()
plt.show()

# %%
import pickle
import numpy as np
import matplotlib.pyplot as plt
# This aggregates all the dirchlets for each k
clients_data = []
# ks = [0, 100, 750, 1500, 3000, 6000]
ks = [0, 100, 750, 1500, 3000, 6000]
for dirichlet in np.linspace(0.1,1, 10):
    dirichlet = round(dirichlet, 1)
    for k in ks:
            path = f"C:\\Users\\LohithSai\\Desktop\\FederatedImputation\\save\\objects\\fedimputed_{k}_{dirichlet}_mnist_exq_15_C[1.0]_iid[2]_E[1]_B[10].pkl"
            with open(path, 'rb') as f:
                clients_data.append(pickle.load(f))
            dirch_metrics = []
            # plt.plot(np.mean(clients_data[-1][1], axis=0), label = f"classifier_{dirichlet}")
            dirch_metrics.append(np.mean(clients_data[-1][1], axis=0))
            dirch_metrics = np.array(dirch_metrics)
            plt.plot(np.mean(dirch_metrics, axis=0), label = f"classifier_dirichlet_{k}")
            print(np.mean(dirch_metrics, axis=0))
            # print(len(np.mean(clients_data[-1][1], axis=0)))
            plt.title(f"Average Test Loss vs Global Round on MNIST for {dirichlet}")
            plt.xlabel('Global Round')
            plt.ylabel('Test Loss')

    plt.legend()
    plt.show()
# Out:
# [23.30030434 16.28657495 44.97928362  8.2500361   6.15898662  4.91661344
#   4.78923443  3.55332266  3.68768243 13.47773985  2.64719641  2.67612217
#   2.37037157  2.28477161  2.06834029]
# [23.94469473 19.25075581 13.79428794 11.244668    9.53789063  7.13056514
#   4.95124675  4.31040802  3.6157291   2.90388786  2.62037583  2.61425995
#   2.51045161  2.20271087  2.25471958]
# [20.63562564 14.96878175  8.8098901   4.64163426  5.82386076  4.13668262
#   2.50671968  2.54329838  2.55278984  1.73063274  2.02281802  2.17230833
#   2.29819798  1.67735046  1.75294471]
# [21.99618909 14.80105139 11.55546837  7.13342471  6.68389318  6.88230369
#   5.52803478  4.39587361  3.51413361  3.34957845  5.420213    3.44758455
#   3.08630218  3.05754442  2.92360414]
# [21.13812153 19.43042425 13.29079259 10.16466369  7.55286457  7.0345305
#   5.83924296  6.5535113   5.83308164  4.99062127  4.50233603  4.98851484
#   4.47793641  4.01047119  3.86635462]
# ...

# %%
run_names = ["run_one", "run_two", "run_three"]
